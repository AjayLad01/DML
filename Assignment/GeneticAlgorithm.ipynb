# %% [markdown]
# <center>Genetic Algorithm</center>

# %%
import random
 
# Number of individuals in each generation
POPULATION_SIZE = 100
 
# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
 
# Target string to be generated
TARGET = "Success and Failure"
 
class Individual(object):
    '''
    Class representing individual in population
    '''
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
 
    @classmethod
    def mutated_genes(self):
        '''
        create random genes for mutation
        '''
        global GENES
        gene = random.choice(GENES)
        return gene
 
    @classmethod
    def create_gnome(self):
        '''
        create chromosome or string of genes
        '''
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
 
    def mate(self, par2):
        '''
        Perform mating and produce new offspring
        '''
 
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):   
 
            # random probability 
            prob = random.random()
 
            # if prob is less than 0.45, insert gene
            # from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
 
            # if prob is between 0.45 and 0.90, insert
            # gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
 
            # otherwise insert random gene(mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
 
        # create new Individual(offspring) using
        # generated chromosome for offspring
        return Individual(child_chromosome)
 
    def cal_fitness(self):
        '''
        Calculate fitness score, it is the number of
        characters in string which differ from target
        string.
        '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
 
# Driver code
def main():
    global POPULATION_SIZE
 
    #current generation
    generation = 1
 
    found = False
    population = []
 
    # create initial population
    for _ in range(POPULATION_SIZE):
                gnome = Individual.create_gnome()
                population.append(Individual(gnome))
 
    while not found:
 
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
 
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
 
        # Otherwise generate new offsprings for new generation
        new_generation = []
 
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
 
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
 
        population = new_generation
 
        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
              "".join(population[0].chromosome),
              population[0].fitness))
 
        generation += 1
 
     
    print("Generation: {}\tString: {}\tFitness: {}".\
          format(generation,
          "".join(population[0].chromosome),
          population[0].fitness))
 
if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: EUFA2s:=pn"r; &-7im	Fitness: 17
# Generation: 2	String: EUFA2s:=pn"r; &-7im	Fitness: 17
# Generation: 3	String: EHcOLsjh"nIz)k[j)/m	Fitness: 16
# Generation: 4	String: ..ca2gA 3xn  1_S6rS	Fitness: 15
# Generation: 5	String: bUKeN[s a("T)PilL@D	Fitness: 14
# Generation: 6	String: zUrXNss 0nK2)aXjueD	Fitness: 13
# Generation: 7	String: zUrXNss 0nK2)aXjueD	Fitness: 13
# Generation: 8	String: SUcbNssdhn%Txai""rd	Fitness: 11
# Generation: 9	String: SUcbNssdhn%Txai""rd	Fitness: 11
# Generation: 10	String:  USUXXs and )4il?rs	Fitness: 10
# Generation: 11	String: S/ce8ss hnd ;ailL;=	Fitness: 8
# Generation: 12	String: S/ce8ss hnd ;ailL;=	Fitness: 8
# Generation: 13	String: SUcO1ss annurailurs	Fitness: 7
# Generation: 14	String: SUcU1ss ann sailurd	Fitness: 6
# Generation: 15	String: SUcU1ss ann sailurd	Fitness: 6
# Generation: 16	String: SUcU1ss ann sailurd	Fitness: 6
# Generation: 17	String: SUcU1ss ann sailurd	Fitness: 6
# Generation: 18	String: SUcW:ss and ;ailurD	Fitness: 5
# Generation: 19	String: SUcW:ss and ;ailurD	Fitness: 5
# Generation: 20	String: SUcW:ss and ;ailurD	Fitness: 5
# Generation: 21	String: SUcW:ss and ;ailurD	Fitness: 5
# Generation: 22	String: SUcW:ss and ;ailurD	Fitness: 5
# Generation: 23	String: SUcW:ss and ;ailurD	Fitness: 5
# Generation: 24	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 25	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 26	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 27	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 28	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 29	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 30	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 31	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 32	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 33	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 34	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 35	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 36	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 37	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 38	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 39	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 40	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 41	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 42	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 43	String: S1cc#ss and (ailurI	Fitness: 4
# Generation: 44	String: SUcciss and (ailure	Fitness: 3
# Generation: 45	String: SUcciss and (ailure	Fitness: 3
# Generation: 46	String: SUcciss and (ailure	Fitness: 3
# Generation: 47	String: SUcciss and (ailure	Fitness: 3
# Generation: 48	String: SUcciss and (ailure	Fitness: 3
# Generation: 49	String: SUcciss and (ailure	Fitness: 3
# Generation: 50	String: SUcciss and (ailure	Fitness: 3
# Generation: 51	String: SUcciss and (ailure	Fitness: 3
# Generation: 52	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 53	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 54	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 55	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 56	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 57	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 58	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 59	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 60	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 61	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 62	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 63	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 64	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 65	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 66	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 67	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 68	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 69	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 70	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 71	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 72	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 73	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 74	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 75	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 76	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 77	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 78	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 79	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 80	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 81	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 82	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 83	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 84	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 85	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 86	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 87	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 88	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 89	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 90	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 91	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 92	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 93	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 94	String: Succ8ss and ;ailure	Fitness: 2
# Generation: 95	String: Success and ;ailure	Fitness: 1
# Generation: 96	String: Success and ;ailure	Fitness: 1
# Generation: 97	String: Success and ;ailure	Fitness: 1
# Generation: 98	String: Success and ;ailure	Fitness: 1
# Generation: 99	String: Success and ;ailure	Fitness: 1
# Generation: 100	String: Success and ;ailure	Fitness: 1
# Generation: 101	String: Success and ;ailure	Fitness: 1
# Generation: 102	String: Success and ;ailure	Fitness: 1
# Generation: 103	String: Success and ;ailure	Fitness: 1
# Generation: 104	String: Success and ;ailure	Fitness: 1
# Generation: 105	String: Success and ;ailure	Fitness: 1
# Generation: 106	String: Success and ;ailure	Fitness: 1
# Generation: 107	String: Success and ;ailure	Fitness: 1
# Generation: 108	String: Success and ;ailure	Fitness: 1
# Generation: 109	String: Success and ;ailure	Fitness: 1
# Generation: 110	String: Success and ;ailure	Fitness: 1
# Generation: 111	String: Success and ;ailure	Fitness: 1
# Generation: 112	String: Success and ;ailure	Fitness: 1
# Generation: 113	String: Success and ;ailure	Fitness: 1
# Generation: 114	String: Success and ;ailure	Fitness: 1
# Generation: 115	String: Success and ;ailure	Fitness: 1
# Generation: 116	String: Success and ;ailure	Fitness: 1
# Generation: 117	String: Success and ;ailure	Fitness: 1
# Generation: 118	String: Success and ;ailure	Fitness: 1
# Generation: 119	String: Success and ;ailure	Fitness: 1
# Generation: 120	String: Success and ;ailure	Fitness: 1
# Generation: 121	String: Success and ;ailure	Fitness: 1
# Generation: 122	String: Success and ;ailure	Fitness: 1
# Generation: 123	String: Success and ;ailure	Fitness: 1
# Generation: 124	String: Success and ;ailure	Fitness: 1
# Generation: 125	String: Success and ;ailure	Fitness: 1
# Generation: 126	String: Success and ;ailure	Fitness: 1
# Generation: 127	String: Success and ;ailure	Fitness: 1
# Generation: 128	String: Success and ;ailure	Fitness: 1
# Generation: 129	String: Success and ;ailure	Fitness: 1
# Generation: 130	String: Success and ;ailure	Fitness: 1
# Generation: 131	String: Success and ;ailure	Fitness: 1
# Generation: 132	String: Success and ;ailure	Fitness: 1
# Generation: 133	String: Success and ;ailure	Fitness: 1
# Generation: 134	String: Success and ;ailure	Fitness: 1
# Generation: 135	String: Success and ;ailure	Fitness: 1
# Generation: 136	String: Success and ;ailure	Fitness: 1
# Generation: 137	String: Success and ;ailure	Fitness: 1
# Generation: 138	String: Success and ;ailure	Fitness: 1
# Generation: 139	String: Success and ;ailure	Fitness: 1
# Generation: 140	String: Success and ;ailure	Fitness: 1
# Generation: 141	String: Success and ;ailure	Fitness: 1
# Generation: 142	String: Success and ;ailure	Fitness: 1
# Generation: 143	String: Success and ;ailure	Fitness: 1
# Generation: 144	String: Success and ;ailure	Fitness: 1
# Generation: 145	String: Success and ;ailure	Fitness: 1
# Generation: 146	String: Success and ;ailure	Fitness: 1
# Generation: 147	String: Success and ;ailure	Fitness: 1
# Generation: 148	String: Success and ;ailure	Fitness: 1
# Generation: 149	String: Success and ;ailure	Fitness: 1
# Generation: 150	String: Success and ;ailure	Fitness: 1
# Generation: 151	String: Success and ;ailure	Fitness: 1
# Generation: 152	String: Success and ;ailure	Fitness: 1
# Generation: 153	String: Success and ;ailure	Fitness: 1
# Generation: 154	String: Success and ;ailure	Fitness: 1
# Generation: 155	String: Success and ;ailure	Fitness: 1
# Generation: 156	String: Success and ;ailure	Fitness: 1
# Generation: 157	String: Success and ;ailure	Fitness: 1
# Generation: 158	String: Success and ;ailure	Fitness: 1
# Generation: 159	String: Success and ;ailure	Fitness: 1
# Generation: 160	String: Success and ;ailure	Fitness: 1
# Generation: 161	String: Success and ;ailure	Fitness: 1
# Generation: 162	String: Success and ;ailure	Fitness: 1
# Generation: 163	String: Success and ;ailure	Fitness: 1
# Generation: 164	String: Success and Failure	Fitness: 0
