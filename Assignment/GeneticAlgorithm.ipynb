# %%
import random
 
# Number of individuals in each generation
POPULATION_SIZE = 100
 
# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
 
# Target string to be generated
TARGET = "Success and Failure"
 
class Individual(object):
    '''
    Class representing individual in population
    '''
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
 
    @classmethod
    def mutated_genes(self):
        '''
        create random genes for mutation
        '''
        global GENES
        gene = random.choice(GENES)
        return gene
 
    @classmethod
    def create_gnome(self):
        '''
        create chromosome or string of genes
        '''
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
 
    def mate(self, par2):
        '''
        Perform mating and produce new offspring
        '''
 
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):   
 
            # random probability 
            prob = random.random()
 
            # if prob is less than 0.45, insert gene
            # from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
 
            # if prob is between 0.45 and 0.90, insert
            # gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
 
            # otherwise insert random gene(mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
 
        # create new Individual(offspring) using
        # generated chromosome for offspring
        return Individual(child_chromosome)
 
    def cal_fitness(self):
        '''
        Calculate fitness score, it is the number of
        characters in string which differ from target
        string.
        '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
 
# Driver code
def main():
    global POPULATION_SIZE
 
    #current generation
    generation = 1
 
    found = False
    population = []
 
    # create initial population
    for _ in range(POPULATION_SIZE):
                gnome = Individual.create_gnome()
                population.append(Individual(gnome))
 
    while not found:
 
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
 
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
 
        # Otherwise generate new offsprings for new generation
        new_generation = []
 
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
 
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
 
        population = new_generation
 
        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
              "".join(population[0].chromosome),
              population[0].fitness))
 
        generation += 1
 
     
    print("Generation: {}\tString: {}\tFitness: {}".\
          format(generation,
          "".join(population[0].chromosome),
          population[0].fitness))
 
if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: zA]OU#66aGb"V;/eD8e	Fitness: 17
# Generation: 2	String: zA]OU#66aGb"V;/eD8e	Fitness: 17
# Generation: 3	String: UydD788 xnls Ui-
# Xn	Fitness: 16
# Generation: 4	String: =7kNhs" enn $qpv3-Z	Fitness: 15
# Generation: 5	String: zAOccs"6Cn,uFsQouT9	Fitness: 14
# Generation: 6	String: zAOccs"6Cn,uFsQouT9	Fitness: 14
# Generation: 7	String: xJOcEsDRand Fp eF0$	Fitness: 12
# Generation: 8	String: Uh]Ce]l snI FUiwuXe	Fitness: 11
# Generation: 9	String: Uh]Ce]l snI FUiwuXe	Fitness: 11
# Generation: 10	String: du3cRsS#anI F&ieF{e	Fitness: 10
# Generation: 11	String: vu3cEsSRand F&ieF0e	Fitness: 9
# Generation: 12	String: vu3cEsSRand F&ieF0e	Fitness: 9
# Generation: 13	String: Su3cEsSRaGd F&ieu0e	Fitness: 8
# Generation: 14	String: SuCcEsS ,nd Fai9F0e	Fitness: 7
# Generation: 15	String: SuCcEsS ,nd Fai9F0e	Fitness: 7
# Generation: 16	String: Su]OesD and
# Fai9uXe	Fitness: 6
# Generation: 17	String: Su]OesD and
# Fai9uXe	Fitness: 6
# Generation: 18	String: Su]OesD and
# Fai9uXe	Fitness: 6
# Generation: 19	String: Su3ces] and
# Fai9u0e	Fitness: 5
# Generation: 20	String: Su3ces] and
# Fai9u0e	Fitness: 5
# Generation: 21	String: SuCcesS and Fai9u0e	Fitness: 4
# Generation: 22	String: SuCcesS and Fai9u0e	Fitness: 4
# Generation: 23	String: SuCcesS and Fai9u0e	Fitness: 4
# Generation: 24	String: SuCcesS and Fai9u0e	Fitness: 4
# Generation: 25	String: SuCcesS and Fai9u0e	Fitness: 4
# Generation: 26	String: SuCcesS and Fai9u0e	Fitness: 4
# Generation: 27	String: SuCcesS and Fai9u0e	Fitness: 4
# Generation: 28	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 29	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 30	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 31	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 32	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 33	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 34	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 35	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 36	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 37	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 38	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 39	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 40	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 41	String: SuccesM and Fai6u}e	Fitness: 3
# Generation: 42	String: Succesy and Fai&ure	Fitness: 2
# Generation: 43	String: Succesy and Fai&ure	Fitness: 2
# Generation: 44	String: Succesy and Fai&ure	Fitness: 2
# Generation: 45	String: Succesy and Fai&ure	Fitness: 2
# Generation: 46	String: Succesy and Fai&ure	Fitness: 2
# Generation: 47	String: Succesy and Fai&ure	Fitness: 2
# Generation: 48	String: Succesy and Fai&ure	Fitness: 2
# Generation: 49	String: Succesy and Fai&ure	Fitness: 2
# Generation: 50	String: Succesy and Fai&ure	Fitness: 2
# Generation: 51	String: Succesy and Fai&ure	Fitness: 2
# Generation: 52	String: Succesy and Fai&ure	Fitness: 2
# Generation: 53	String: Succesy and Fai&ure	Fitness: 2
# Generation: 54	String: Succesy and Fai&ure	Fitness: 2
# Generation: 55	String: Succesy and Fai&ure	Fitness: 2
# Generation: 56	String: Succesy and Fai&ure	Fitness: 2
# Generation: 57	String: Succesy and Fai&ure	Fitness: 2
# Generation: 58	String: Succesy and Fai&ure	Fitness: 2
# Generation: 59	String: Succesy and Fai&ure	Fitness: 2
# Generation: 60	String: Succesy and Fai&ure	Fitness: 2
# Generation: 61	String: Succesy and Fai&ure	Fitness: 2
# Generation: 62	String: Succesy and Fai&ure	Fitness: 2
# Generation: 63	String: Succesy and Fai&ure	Fitness: 2
# Generation: 64	String: Succesy and Fai&ure	Fitness: 2
# Generation: 65	String: Succesy and Fai&ure	Fitness: 2
# Generation: 66	String: Succesy and Fai&ure	Fitness: 2
# Generation: 67	String: Succesy and Fai&ure	Fitness: 2
# Generation: 68	String: Succesy and Fai&ure	Fitness: 2
# Generation: 69	String: Succesy and Fai&ure	Fitness: 2
# Generation: 70	String: Succesy and Fai&ure	Fitness: 2
# Generation: 71	String: Succesy and Fai&ure	Fitness: 2
# Generation: 72	String: Succesy and Fai&ure	Fitness: 2
# Generation: 73	String: Succesy and Fai&ure	Fitness: 2
# Generation: 74	String: Succesy and Fai&ure	Fitness: 2
# Generation: 75	String: Succesy and Fai&ure	Fitness: 2
# Generation: 76	String: Succesy and Fai&ure	Fitness: 2
# Generation: 77	String: Succesy and Fai&ure	Fitness: 2
# Generation: 78	String: Success and Fai9ure	Fitness: 1
# Generation: 79	String: Success and Fai9ure	Fitness: 1
# Generation: 80	String: Success and Fai9ure	Fitness: 1
# Generation: 81	String: Success and Fai9ure	Fitness: 1
# Generation: 82	String: Success and Fai9ure	Fitness: 1
# Generation: 83	String: Success and Fai9ure	Fitness: 1
# Generation: 84	String: Success and Fai9ure	Fitness: 1
# Generation: 85	String: Success and Fai9ure	Fitness: 1
# Generation: 86	String: Success and Fai9ure	Fitness: 1
# Generation: 87	String: Success and Fai9ure	Fitness: 1
# Generation: 88	String: Success and Failure	Fitness: 0
